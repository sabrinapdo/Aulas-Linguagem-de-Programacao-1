# %%
def exibir_menu():
    print("-"*30)
    print("menu de estoque")
    print("-"*30)
    print("1. Adicionar novo produto")
    print("2. Listar produtos em estoque")
    print("3. Sair")
    print("-" * 30)

# %%
def exibir_menu():
    print("-"*30)
    print("MENU DE ESTOQUE          ")
    print("-" * 30)
    print("1. Adicionar novo produto")
    print("2. Listar produtos em estoque")
    print("3. Sair")
    print("-"*30)

    nome_produto_1 = ""
    quantidade_produto_1 = 0
    preco_produto_1 = 0.0
    rodando = True

    while rodando:

        exibir_menu() #--Aqui está a chamada da função

        #---Continuação do programa exatamente igual

# %%
# Código sem função 
nota1 = 7.5
nota2 = 8
media = (nota1 + nota2) / 2 
print(f"A média é:{media} ")

nota3 = 6.0;
nota4 = 9.0
media2 = (nota3 + nota4 ) / 2 
print(f"M média é: {media2}")

# %%
def calcular_e_exibir_media(nota1, nota2):
    media = (nota1 + nota2) / 2
    print(f"A média é: {media}")

# %%
def calcular_e_exibir_media(nota1, nota2):
    media = (nota1 + nota2) / 2
    print(f"A média é: {media}")

calcular_e_exibir_media(7.5, 8.0)
calcular_e_exibir_media(6.0, 9.0)
