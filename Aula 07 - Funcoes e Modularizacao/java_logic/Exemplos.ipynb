# %%
public class Exemplos {

    public static void exibirMenu() {
        system.out.println("---------------------------");
        system.out.println("MENU DE ESTOQUE");
        system.out.println("---------------------------");
        system.out.println("1. Adicionar novo produto");
        system.out.println("2. Listar produtos em estoque");
        system.out.println("3. Sair");
        system.out.println("---------------------------");
    }
    public static void cod1Exemplo1(String[] args){
        //Programa principal
    }
}

# %%
import java.util.scanner;

public class Exemplos {
    public static void exibirMenu() {..} //bloco recolhido

    public static void Main(String[] args) {

        String nomeProduto1 = "";
        int quantidadeProduto1 = 0;
        double precoProduto1 = 0.0;
        boolean rodando = true; 

        while (rodando) {
            
            exibirMenu(); //--Chamada da função

            //Continuação do código
        }
    } 
}

# %%
public class Exemplos {
    public static void main(String[] args) {
        Scanner scanner = new Scanner(System.in);

        double nota1, nota2, nota3, nota4;
        double media = 0, media2 = 0;

        nota1 = 7.5;
        nota2 = 8.0;
        media = (nota1 + nota2) / 2;
        System.out.println("A média é: " + media);

        nota3 = 6.0;
        nota4 = 9.0;
        media2 = (nota3 + nota4) / 2;
        System.out.println("A média é: " + media2);

        scanner.close();
    }
}

# %%
public class Exemplos {
    public static void calcularEExibirMedia(double nota1, double nota2) {
        double media = (nota1 + nota2) / 2;
        System.out.println("A media eh: " + media);
    }
}

# %%
import java.util.Scanner;

public class Exemplos {
    public static void calcularEExibirMedia(double nota1, double nota2) {
        double media = (nota1 + nota2) / 2;
        System.out.println("A media eh: " + media);
    }

    public static void main(String[] args) {
        Scanner scanner = new Scanner(System.in);

        calcularEExibirMedia(7.5, 8.0);
        calcularEExibirMedia(6.0, 9.0);

        scanner.close();
    }
}
